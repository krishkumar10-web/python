# %%
print(ord("a"))
# Out:
# 97

# %%
print(ord("A"))
# Out:
# 65

# %%
print(chr(65))
# Out:
# A

# %%
print(chr(97))
# Out:
# a

# %%
print("car">"cat")
# Out:
# False

# %%
ord("t")
# Out:
# 116

# %%
a='''krish
harsh
arjun'''
print(a)
# Out:
# krish
# harsh
# arjun

# %%
'''krish is hero'''
a = 'sahil'
b= "sahil"
c='''sa

hil'''
d="""sah


il"""
print(a)
print(b)
print(c)
print(d)
# Out:
# sahil
# sahil
# sa
#
# hil
# sah
#
#
# il

# %%
a=str(98)
print(a)
# Out:
# 98

# %%
print("krish\nkumar")
# Out:
# krish
# kumar

# %%
a="KrIsH"
b=a.swapcase()
print(b)
# Out:
# kRiSh

# %%
a="KrIsH"
b=a.center(50)
print(b)
# Out:
#                       KrIsH

# %%
"42".zfill(20)
# Out:
# '00000000000000000042'

# %%
"python".index("p")
# Out:
# 0

# %%
"banana".count("a")
# Out:
# 3

# %%
"banana".endswith("a")
# Out:
# True

# %%
"banana".startswith("b")
# Out:
# True

# %%
a="KrIsH"
b=a.ljust(50)
print(b)
# Out:
# KrIsH

# %%
a="KrIsH"
b=a.rjust(50)
print(b)
# Out:
#                                              KrIsH

# %%
"Quad".isalpha()
# Out:
# True

# %%
"Quad1232".isalnum()
# Out:
# True

# %%
"123".isdigit()
# Out:
# True

# %%
"123".isnumeric()
# Out:
# True

# %%
" ".isspace()
# Out:
# True

# %%
"".isspace()
# Out:
# False

# %%
"12".isdecimal()
# Out:
# True

# %%
a="krish"
print(a[0:3])
# Out:
# kri
