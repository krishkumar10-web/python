# %%
print("krish")
# Out:
# krish

# %%
a="krish"
print(type(a))
# Out:
# <class 'str'>

# %%
a=123
print(type(a))
# Out:
# <class 'int'>

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
a=12.10
print(type(a))
# Out:
# <class 'float'>

# %%
name=["krish","harsh"]
print(type(name))
print(name)
# Out:
# <class 'list'>
# ['krish', 'harsh']

# %%
age={23,34,34}
print(type(age))
print(age)
# Out:
# <class 'set'>
# {34, 23}

# %%
item=("krish","dsp road",23,78)
print(item)
print(type(item))
# Out:
# ('krish', 'dsp road', 23, 78)
# <class 'tuple'>

# %%
num={"krish":23,"harsh":34}
print(type(num))
print(num)
# Out:
# <class 'dict'>
# {'krish': 23, 'harsh': 34}

# %%
# comment
# we understand how we comment any line
''' this is a multiline comment'''
# Out:
# ' this is a multiline comment'
