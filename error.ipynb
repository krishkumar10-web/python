# %%
# errors of python

# %%
# Name error
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Name error
# ----> 2 print(name)
#
# NameError: name 'name' is not defined

# %%
# Indentation error
if num%2==0:
print(num)
# Out:
#   Cell In[2], line 3
#     print(num)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# syntax error
if true
  print(krish)
# Out:
#   Cell In[3], line 2
#     if true
#            ^
# SyntaxError: expected ':'

# %%
# zero divison error
a=33
b=0
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 # zero divison error
#       2 a=33
#       3 b=0
# ----> 4 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
# value error
a=int(input("age"))
print(a)
# Out:
# age krish
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # value error
# ----> 2 a=int(input("age"))
#       3 print(a)
#
# ValueError: invalid literal for int() with base 10: 'krish'

# %%
#  type error
marks="23"+32
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #  type error
# ----> 2 marks="23"+32
#
# TypeError: can only concatenate str (not "int") to str

# %%
# attribute error
text="krish"
text.append("kumar")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 # attribute error
#       2 text="krish"
# ----> 3 text.append("kumar")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# index error
my_index = [1,2,3,4]
print(my_index[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 # index error
#       2 my_index = [1,2,3,4]
# ----> 3 print(my_index[6])
#
# IndexError: list index out of range

# %%
# logic error
# wap  print 1 to 100
while i>10:
    print(i)
# this arries a infinte loop due to a opeator

# %%
# module not found
import krish
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 # module not found
# ----> 2 import krish
#
# ModuleNotFoundError: No module named 'krish'

# %%
# file not found
with open("damodar sir" , "r") as f:
    content=f.read
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # file not found
# ----> 2 with open("damodar sir" , "r") as f:
#       3     content=f.read
#
# FileNotFoundError: [Errno 2] No such file or directory: 'damodar sir'

# %%
# key error
my_name={"krish":"20"}
print(my_name["age"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 3
#       1 # key error
#       2 my_name={"krish":"20"}
# ----> 3 print(my_name["age"])
#
# KeyError: 'age'
